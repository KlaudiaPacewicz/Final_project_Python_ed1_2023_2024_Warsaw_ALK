# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import input data

# %%
r2 = pd.read_excel('./../../original_input_data/clinical_metadata/Repository2_sample_clinical_metadata.xlsx')
r2
# Out:
#       SAMPLE_ID disease_status_last_followup  donor_age_at_diagnosis  \
# 0   Sample_0135                      relapse                      54
# 1   Sample_0136                  progression                      54
# 2   Sample_0137                      relapse                      52
# 3   Sample_0138                      relapse                      52
# 4   Sample_0139                      relapse                      60
# ..          ...                          ...                     ...
# 74  Sample_0209                      relapse                      58
# 75  Sample_0210                      relapse                      60
# 76  Sample_0211                      relapse                      74
# 77  Sample_0212                      relapse                      73
# 78  Sample_0213                      relapse                      52
#
#     donor_relapse_interval_days  donor_survival_time_days  primary_tumor  \
# 0                          21.0                       477              1
# 1                           NaN                       184              1
# 2                         167.0                       972              1
# 3                         381.0                      1699              1
# 4                         175.0                       684              1
# ..                          ...                       ...            ...
# 74                         37.0                       195              1
# 75                         21.0                       393              1
# 76                         21.0                       205              1
# 77                        293.0                       804              1
# 78                        237.0                       734              1
#
#     metastatic_tumor  family_history_of_cancer
# 0                  0                         0
# 1                  0                         0
# 2                  0                         0
# 3                  1                         1
# 4                  0                         0
# ..               ...                       ...
# 74                 0                         0
# 75                 0                         0
# 76                 0                         0
# 77                 0                         0
# 78                 0                         0
#
# [79 rows x 8 columns]

# %% [markdown]
# ## Replace NA with NaN/NaT values

# %% [markdown]
# r2 = r2.replace(r'N/A', np.nan, regex=True)

# %% [markdown]
# ## Calculation of progression-free survival period (months)

# %%
r2["progression_free_survival_months"] = round(r2["donor_relapse_interval_days"] / 30.41)
r2
# Out:
#       SAMPLE_ID disease_status_last_followup  donor_age_at_diagnosis  \
# 0   Sample_0135                      relapse                      54
# 1   Sample_0136                  progression                      54
# 2   Sample_0137                      relapse                      52
# 3   Sample_0138                      relapse                      52
# 4   Sample_0139                      relapse                      60
# ..          ...                          ...                     ...
# 74  Sample_0209                      relapse                      58
# 75  Sample_0210                      relapse                      60
# 76  Sample_0211                      relapse                      74
# 77  Sample_0212                      relapse                      73
# 78  Sample_0213                      relapse                      52
#
#     donor_relapse_interval_days  donor_survival_time_days  primary_tumor  \
# 0                          21.0                       477              1
# 1                           NaN                       184              1
# 2                         167.0                       972              1
# 3                         381.0                      1699              1
# 4                         175.0                       684              1
# ..                          ...                       ...            ...
# 74                         37.0                       195              1
# 75                         21.0                       393              1
# 76                         21.0                       205              1
# 77                        293.0                       804              1
# 78                        237.0                       734              1
#
#     metastatic_tumor  family_history_of_cancer  \
# 0                  0                         0
# 1                  0                         0
# 2                  0                         0
# 3                  1                         1
# 4                  0                         0
# ..               ...                       ...
# 74                 0                         0
# 75                 0                         0
# 76                 0                         0
# 77                 0                         0
# 78                 0                         0
#
#     progression_free_survival_months
# 0                                1.0
# 1                                NaN
# 2                                5.0
# 3                               13.0
# 4                                6.0
# ..                               ...
# 74                               1.0
# 75                               1.0
# 76                               1.0
# 77                              10.0
# 78                               8.0
#
# [79 rows x 9 columns]

# %% [markdown]
# ## Calculation of overal survival period (months)

# %%
r2["overal_survival_months"] = round(r2["donor_survival_time_days"] / 30.41)
r2
# Out:
#       SAMPLE_ID disease_status_last_followup  donor_age_at_diagnosis  \
# 0   Sample_0135                      relapse                      54
# 1   Sample_0136                  progression                      54
# 2   Sample_0137                      relapse                      52
# 3   Sample_0138                      relapse                      52
# 4   Sample_0139                      relapse                      60
# ..          ...                          ...                     ...
# 74  Sample_0209                      relapse                      58
# 75  Sample_0210                      relapse                      60
# 76  Sample_0211                      relapse                      74
# 77  Sample_0212                      relapse                      73
# 78  Sample_0213                      relapse                      52
#
#     donor_relapse_interval_days  donor_survival_time_days  primary_tumor  \
# 0                          21.0                       477              1
# 1                           NaN                       184              1
# 2                         167.0                       972              1
# 3                         381.0                      1699              1
# 4                         175.0                       684              1
# ..                          ...                       ...            ...
# 74                         37.0                       195              1
# 75                         21.0                       393              1
# 76                         21.0                       205              1
# 77                        293.0                       804              1
# 78                        237.0                       734              1
#
#     metastatic_tumor  family_history_of_cancer  \
# 0                  0                         0
# 1                  0                         0
# 2                  0                         0
# 3                  1                         1
# 4                  0                         0
# ..               ...                       ...
# 74                 0                         0
# 75                 0                         0
# 76                 0                         0
# 77                 0                         0
# 78                 0                         0
#
#     progression_free_survival_months  overal_survival_months
# 0                                1.0                    16.0
# 1                                NaN                     6.0
# 2                                5.0                    32.0
# 3                               13.0                    56.0
# 4                                6.0                    22.0
# ..                               ...                     ...
# 74                               1.0                     6.0
# 75                               1.0                    13.0
# 76                               1.0                     7.0
# 77                              10.0                    26.0
# 78                               8.0                    24.0
#
# [79 rows x 10 columns]

# %% [markdown]
# ## Labels preparation

# %%
def sample_labeling(x):
    if x['disease_status_last_followup'] == "complete remission":
            return 'possible_responder'
    if x['disease_status_last_followup'] == "relapse" or x['disease_status_last_followup'] == "progression" :
        if x["progression_free_survival_months"] >= 6:
            return 'possible_responder'
        else:
            return 'possible_nonresponder'
    else:
        return 'other_use_as_test'

# Test for sample_labeling function

#x_test = {
    #'disease_status_last_followup': "relapse",
    #'progression_free_survival_months': 2,
#}

#result = sample_labeling(x_test)

r2['label'] = r2.apply(sample_labeling, axis=1)
r2
# Out:
#       SAMPLE_ID disease_status_last_followup  donor_age_at_diagnosis  \
# 0   Sample_0135                      relapse                      54
# 1   Sample_0136                  progression                      54
# 2   Sample_0137                      relapse                      52
# 3   Sample_0138                      relapse                      52
# 4   Sample_0139                      relapse                      60
# ..          ...                          ...                     ...
# 74  Sample_0209                      relapse                      58
# 75  Sample_0210                      relapse                      60
# 76  Sample_0211                      relapse                      74
# 77  Sample_0212                      relapse                      73
# 78  Sample_0213                      relapse                      52
#
#     donor_relapse_interval_days  donor_survival_time_days  primary_tumor  \
# 0                          21.0                       477              1
# 1                           NaN                       184              1
# 2                         167.0                       972              1
# 3                         381.0                      1699              1
# 4                         175.0                       684              1
# ..                          ...                       ...            ...
# 74                         37.0                       195              1
# 75                         21.0                       393              1
# 76                         21.0                       205              1
# 77                        293.0                       804              1
# 78                        237.0                       734              1
#
#     metastatic_tumor  family_history_of_cancer  \
# 0                  0                         0
# 1                  0                         0
# 2                  0                         0
# 3                  1                         1
# 4                  0                         0
# ..               ...                       ...
# 74                 0                         0
# 75                 0                         0
# 76                 0                         0
# 77                 0                         0
# 78                 0                         0
#
#     progression_free_survival_months  overal_survival_months  \
# 0                                1.0                    16.0
# 1                                NaN                     6.0
# 2                                5.0                    32.0
# 3                               13.0                    56.0
# 4                                6.0                    22.0
# ..                               ...                     ...
# 74                               1.0                     6.0
# 75                               1.0                    13.0
# 76                               1.0                     7.0
# 77                              10.0                    26.0
# 78                               8.0                    24.0
#
#                     label
# 0   possible_nonresponder
# 1   possible_nonresponder
# 2   possible_nonresponder
# 3      possible_responder
# 4      possible_responder
# ..                    ...
# 74  possible_nonresponder
# 75  possible_nonresponder
# 76  possible_nonresponder
# 77     possible_responder
# 78     possible_responder
#
# [79 rows x 11 columns]

# %% [markdown]
# ## Save preprocessed clinical metadata for repository 2

# %%
r2.to_csv('Repository2_clinical_metadata_cleaned.csv')

# %% [markdown]
# ## Extraction of samples with labels

# %%
r2_labels = r2[['SAMPLE_ID', 'label']]
r2_labels = r2_labels[r2_labels['label'].isin(['possible_responder', 'possible_nonresponder'])]
r2_labels.to_csv('Repository2_samples_with_labels.csv')
r2_labels
# Out:
#       SAMPLE_ID                  label
# 0   Sample_0135  possible_nonresponder
# 1   Sample_0136  possible_nonresponder
# 2   Sample_0137  possible_nonresponder
# 3   Sample_0138     possible_responder
# 4   Sample_0139     possible_responder
# ..          ...                    ...
# 74  Sample_0209  possible_nonresponder
# 75  Sample_0210  possible_nonresponder
# 76  Sample_0211  possible_nonresponder
# 77  Sample_0212     possible_responder
# 78  Sample_0213     possible_responder
#
# [79 rows x 2 columns]

# %% [markdown]
# ## Extraction of clinical features - being further used for correlation with genetic features

# %%
r2_clinical_features = r2[['SAMPLE_ID', 'donor_age_at_diagnosis', 'primary_tumor', 'metastatic_tumor', 'family_history_of_cancer']]

r2_clinical_features.to_csv('./../../clinical_features/Repository2_clinical_features.csv')
