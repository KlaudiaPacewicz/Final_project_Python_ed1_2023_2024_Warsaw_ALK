# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import labels from all repositories

# %%
r1_labels = pd.read_csv('./../../labels/basis_for_sample_labeling/Repository1_samples_with_labels.csv')
r2_labels = pd.read_csv('./../../labels/basis_for_sample_labeling/Repository2_samples_with_labels.csv')
r3_labels = pd.read_csv('./../../labels/basis_for_sample_labeling/Repository3_samples_with_labels.csv')

# %% [markdown]
# ## Preparation of labels from repository 1

# %%
r1_labels.drop(columns='Unnamed: 0', axis='columns')
# Out:
#       SAMPLE_ID                      label
# 0   Sample_0003             true_responder
# 1   Sample_0004     responder_based_on_PFS
# 2   Sample_0006  nonresponder_based_on_PFS
# 3   Sample_0009      responder_based_on_SD
# 4   Sample_0011     responder_based_on_PFS
# 5   Sample_0012   nonresponder_based_on_SD
# 6   Sample_0013             true_responder
# 7   Sample_0014   nonresponder_based_on_SD
# 8   Sample_0015             true_responder
# 9   Sample_0016             true_responder
# 10  Sample_0017  nonresponder_based_on_PFS
# 11  Sample_0018          true_nonresponder
# 12  Sample_0019             true_responder
# 13  Sample_0020             true_responder
# 14  Sample_0022             true_responder
# 15  Sample_0023          true_nonresponder
# 16  Sample_0024   nonresponder_based_on_SD
# 17  Sample_0025             true_responder
# 18  Sample_0026      responder_based_on_SD
# 19  Sample_0027          true_nonresponder
# 20  Sample_0030             true_responder
# 21  Sample_0031             true_responder
# 22  Sample_0032      responder_based_on_SD
# 23  Sample_0033     responder_based_on_PFS
# 24  Sample_0034             true_responder
# 25  Sample_0035             true_responder
# 26  Sample_0037             true_responder
# 27  Sample_0038   nonresponder_based_on_SD
# 28  Sample_0039             true_responder
# 29  Sample_0040   nonresponder_based_on_SD
# 30  Sample_0043             true_responder
# 31  Sample_0044             true_responder
# 32  Sample_0045      responder_based_on_SD
# 33  Sample_0047             true_responder
# 34  Sample_0052             true_responder
# 35  Sample_0053      responder_based_on_SD
# 36  Sample_0057     responder_based_on_PFS
# 37  Sample_0062             true_responder
# 38  Sample_0074   nonresponder_based_on_SD
# 39  Sample_0083          true_nonresponder
# 40  Sample_0085             true_responder
# 41  Sample_0086             true_responder
# 42  Sample_0087             true_responder
# 43  Sample_0088             true_responder
# 44  Sample_0089          true_nonresponder
# 45  Sample_0090   nonresponder_based_on_SD
# 46  Sample_0091             true_responder
# 47  Sample_0092             true_responder
# 48  Sample_0093     responder_based_on_PFS
# 49  Sample_0094             true_responder
# 50  Sample_0095   nonresponder_based_on_SD
# 51  Sample_0097      responder_based_on_SD
# 52  Sample_0099          true_nonresponder
# 53  Sample_0100          true_nonresponder
# 54  Sample_0101   nonresponder_based_on_SD
# 55  Sample_0103   nonresponder_based_on_SD
# 56  Sample_0105             true_responder
# 57  Sample_0106             true_responder
# 58  Sample_0107   nonresponder_based_on_SD
# 59  Sample_0108             true_responder
# 60  Sample_0109             true_responder
# 61  Sample_0110  nonresponder_based_on_PFS
# 62  Sample_0111   nonresponder_based_on_SD
# 63  Sample_0112             true_responder
# 64  Sample_0114             true_responder
# 65  Sample_0115   nonresponder_based_on_SD
# 66  Sample_0116   nonresponder_based_on_SD
# 67  Sample_0117     responder_based_on_PFS
# 68  Sample_0118             true_responder
# 69  Sample_0119     responder_based_on_PFS
# 70  Sample_0120  nonresponder_based_on_PFS
# 71  Sample_0122      responder_based_on_SD
# 72  Sample_0123          true_nonresponder
# 73  Sample_0124          true_nonresponder
# 74  Sample_0125  nonresponder_based_on_PFS
# 75  Sample_0126  nonresponder_based_on_PFS
# 76  Sample_0128      responder_based_on_SD
# 77  Sample_0131             true_responder
# 78  Sample_0133   nonresponder_based_on_SD
# 79  Sample_0134   nonresponder_based_on_SD

# %%
r1_labels_v1 = r1_labels

# %%
r1_labels_v1['labels_v1'] = r1_labels_v1['label'].replace({'true_responder': 1,'responder_based_on_PFS': 1, 'responder_based_on_SD': 1, 'true_nonresponder': 0, 'nonresponder_based_on_SD': 0,'nonresponder_based_on_PFS': 0})
pd.set_option('display.max_rows', None)

r1_labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
# Out:
# /tmp/ipykernel_5088/3065554469.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   r1_labels_v1['labels_v1'] = r1_labels_v1['label'].replace({'true_responder': 1,'responder_based_on_PFS': 1, 'responder_based_on_SD': 1, 'true_nonresponder': 0, 'nonresponder_based_on_SD': 0,'nonresponder_based_on_PFS': 0})
#       SAMPLE_ID  labels_v1
# 0   Sample_0003          1
# 1   Sample_0004          1
# 2   Sample_0006          0
# 3   Sample_0009          1
# 4   Sample_0011          1
# 5   Sample_0012          0
# 6   Sample_0013          1
# 7   Sample_0014          0
# 8   Sample_0015          1
# 9   Sample_0016          1
# 10  Sample_0017          0
# 11  Sample_0018          0
# 12  Sample_0019          1
# 13  Sample_0020          1
# 14  Sample_0022          1
# 15  Sample_0023          0
# 16  Sample_0024          0
# 17  Sample_0025          1
# 18  Sample_0026          1
# 19  Sample_0027          0
# 20  Sample_0030          1
# 21  Sample_0031          1
# 22  Sample_0032          1
# 23  Sample_0033          1
# 24  Sample_0034          1
# 25  Sample_0035          1
# 26  Sample_0037          1
# 27  Sample_0038          0
# 28  Sample_0039          1
# 29  Sample_0040          0
# 30  Sample_0043          1
# 31  Sample_0044          1
# 32  Sample_0045          1
# 33  Sample_0047          1
# 34  Sample_0052          1
# 35  Sample_0053          1
# 36  Sample_0057          1
# 37  Sample_0062          1
# 38  Sample_0074          0
# 39  Sample_0083          0
# 40  Sample_0085          1
# 41  Sample_0086          1
# 42  Sample_0087          1
# 43  Sample_0088          1
# 44  Sample_0089          0
# 45  Sample_0090          0
# 46  Sample_0091          1
# 47  Sample_0092          1
# 48  Sample_0093          1
# 49  Sample_0094          1
# 50  Sample_0095          0
# 51  Sample_0097          1
# 52  Sample_0099          0
# 53  Sample_0100          0
# 54  Sample_0101          0
# 55  Sample_0103          0
# 56  Sample_0105          1
# 57  Sample_0106          1
# 58  Sample_0107          0
# 59  Sample_0108          1
# 60  Sample_0109          1
# 61  Sample_0110          0
# 62  Sample_0111          0
# 63  Sample_0112          1
# 64  Sample_0114          1
# 65  Sample_0115          0
# 66  Sample_0116          0
# 67  Sample_0117          1
# 68  Sample_0118          1
# 69  Sample_0119          1
# 70  Sample_0120          0
# 71  Sample_0122          1
# 72  Sample_0123          0
# 73  Sample_0124          0
# 74  Sample_0125          0
# 75  Sample_0126          0
# 76  Sample_0128          1
# 77  Sample_0131          1
# 78  Sample_0133          0
# 79  Sample_0134          0

# %% [markdown]
# ## Preparation of labels from repository 2

# %%
r2_labels
r2_labels_v1['labels_v1'] = r2_labels_v1['label'].replace({'possible_responder': 1, 'possible_nonresponder': 0})
pd.set_option('display.max_rows', None)

r2_labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
# Out:
# /tmp/ipykernel_5088/3971461155.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   r2_labels_v1['labels_v1'] = r2_labels_v1['label'].replace({'possible_responder': 1, 'possible_nonresponder': 0})
#       SAMPLE_ID  labels_v1
# 0   Sample_0135          0
# 1   Sample_0136          0
# 2   Sample_0137          0
# 3   Sample_0138          1
# 4   Sample_0139          1
# 5   Sample_0140          0
# 6   Sample_0141          0
# 7   Sample_0142          0
# 8   Sample_0143          0
# 9   Sample_0144          1
# 10  Sample_0145          0
# 11  Sample_0146          1
# 12  Sample_0147          1
# 13  Sample_0148          1
# 14  Sample_0149          0
# 15  Sample_0150          0
# 16  Sample_0151          0
# 17  Sample_0152          0
# 18  Sample_0153          0
# 19  Sample_0154          0
# 20  Sample_0155          0
# 21  Sample_0156          0
# 22  Sample_0157          1
# 23  Sample_0158          1
# 24  Sample_0159          1
# 25  Sample_0160          1
# 26  Sample_0161          1
# 27  Sample_0162          1
# 28  Sample_0163          1
# 29  Sample_0164          1
# 30  Sample_0165          0
# 31  Sample_0166          0
# 32  Sample_0167          0
# 33  Sample_0168          0
# 34  Sample_0169          0
# 35  Sample_0170          0
# 36  Sample_0171          0
# 37  Sample_0172          0
# 38  Sample_0173          0
# 39  Sample_0174          1
# 40  Sample_0175          0
# 41  Sample_0176          0
# 42  Sample_0177          0
# 43  Sample_0178          0
# 44  Sample_0179          1
# 45  Sample_0180          1
# 46  Sample_0181          1
# 47  Sample_0182          1
# 48  Sample_0183          1
# 49  Sample_0184          0
# 50  Sample_0185          1
# 51  Sample_0186          1
# 52  Sample_0187          1
# 53  Sample_0188          1
# 54  Sample_0189          1
# 55  Sample_0190          1
# 56  Sample_0191          1
# 57  Sample_0192          1
# 58  Sample_0193          1
# 59  Sample_0194          1
# 60  Sample_0195          1
# 61  Sample_0196          1
# 62  Sample_0197          1
# 63  Sample_0198          1
# 64  Sample_0199          0
# 65  Sample_0200          0
# 66  Sample_0201          0
# 67  Sample_0202          0
# 68  Sample_0203          0
# 69  Sample_0204          0
# 70  Sample_0205          0
# 71  Sample_0206          0
# 72  Sample_0207          0
# 73  Sample_0208          0
# 74  Sample_0209          0
# 75  Sample_0210          0
# 76  Sample_0211          0
# 77  Sample_0212          1
# 78  Sample_0213          1

# %% [markdown]
# ## Preparation of labels from repository 3

# %%
r3_labels_v1 = r3_labels
r3_labels_v1['labels_v1'] = r3_labels_v1['label'].replace({'true_responder': 1,'responder_based_on_PFS': 1, 'true_nonresponder': 0})
r3_labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
# Out:
# /tmp/ipykernel_5088/3127744932.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   r3_labels_v1['labels_v1'] = r3_labels_v1['label'].replace({'true_responder': 1,'responder_based_on_PFS': 1, 'true_nonresponder': 0})
#       SAMPLE_ID  labels_v1
# 0   Sample_0214          1
# 1   Sample_0215          1
# 2   Sample_0216          1
# 3   Sample_0217          1
# 4   Sample_0218          1
# 5   Sample_0219          1
# 6   Sample_0220          1
# 7   Sample_0221          1
# 8   Sample_0222          1
# 9   Sample_0223          0
# 10  Sample_0224          1
# 11  Sample_0225          1
# 12  Sample_0226          1
# 13  Sample_0227          1
# 14  Sample_0228          1
# 15  Sample_0229          1
# 16  Sample_0230          1
# 17  Sample_0231          1
# 18  Sample_0232          1
# 19  Sample_0233          1
# 20  Sample_0234          1
# 21  Sample_0235          1
# 22  Sample_0236          1
# 23  Sample_0237          1
# 24  Sample_0238          1
# 25  Sample_0239          1
# 26  Sample_0240          1
# 27  Sample_0241          1
# 28  Sample_0242          1
# 29  Sample_0243          1
# 30  Sample_0244          1
# 31  Sample_0245          1
# 32  Sample_0246          1
# 33  Sample_0247          1
# 34  Sample_0248          1
# 35  Sample_0249          1
# 36  Sample_0250          1
# 37  Sample_0251          1
# 38  Sample_0252          1
# 39  Sample_0253          1
# 40  Sample_0254          1
# 41  Sample_0255          1

# %% [markdown]
# ## Merge all labels v1

# %%
labels_v1 = pd.concat([r1_labels_v1, r2_labels_v1, r3_labels_v1], ignore_index=True)
labels_v1 = labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
labels_v1.to_csv('labels_v1.csv')
