# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import labels from all repositories

# %%
r1_labels = pd.read_csv('./../../labels/basis_for_sample_labeling/Repository1_samples_with_labels.csv')
r2_labels = pd.read_csv('./../../labels/basis_for_sample_labeling/Repository2_samples_with_labels.csv')
r3_labels = pd.read_csv('./../../labels/basis_for_sample_labeling/Repository3_samples_with_labels.csv')

# %% [markdown]
# ## Preparation of labels from repository 1

# %%
r1_labels.drop(columns='Unnamed: 0', axis='columns')
# Out:
#       SAMPLE_ID                      label
# 0   Sample_0003             true_responder
# 1   Sample_0004     responder_based_on_PFS
# 2   Sample_0006  nonresponder_based_on_PFS
# 3   Sample_0009      responder_based_on_SD
# 4   Sample_0011     responder_based_on_PFS
# ..          ...                        ...
# 75  Sample_0126  nonresponder_based_on_PFS
# 76  Sample_0128      responder_based_on_SD
# 77  Sample_0131             true_responder
# 78  Sample_0133   nonresponder_based_on_SD
# 79  Sample_0134   nonresponder_based_on_SD
#
# [80 rows x 2 columns]

# %%
r1_labels_v1 = r1_labels

# %%
r1_labels_v1['labels_v1'] = r1_labels_v1['label'].replace({'true_responder': 1,'responder_based_on_PFS': 1, 'responder_based_on_SD': 1, 'true_nonresponder': 0, 'nonresponder_based_on_SD': 0,'nonresponder_based_on_PFS': 0})
pd.set_option('display.max_rows', None)

r1_labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
# Out:
# /tmp/ipykernel_29493/3065554469.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   r1_labels_v1['labels_v1'] = r1_labels_v1['label'].replace({'true_responder': 1,'responder_based_on_PFS': 1, 'responder_based_on_SD': 1, 'true_nonresponder': 0, 'nonresponder_based_on_SD': 0,'nonresponder_based_on_PFS': 0})
#       SAMPLE_ID  labels_v1
# 0   Sample_0003          1
# 1   Sample_0004          1
# 2   Sample_0006          0
# 3   Sample_0009          1
# 4   Sample_0011          1
# 5   Sample_0012          0
# 6   Sample_0013          1
# 7   Sample_0014          0
# 8   Sample_0015          1
# 9   Sample_0016          1
# 10  Sample_0017          0
# 11  Sample_0018          0
# 12  Sample_0019          1
# 13  Sample_0020          1
# 14  Sample_0022          1
# 15  Sample_0023          0
# 16  Sample_0024          0
# 17  Sample_0025          1
# 18  Sample_0026          1
# 19  Sample_0027          0
# 20  Sample_0030          1
# 21  Sample_0031          1
# 22  Sample_0032          1
# 23  Sample_0033          1
# 24  Sample_0034          1
# 25  Sample_0035          1
# 26  Sample_0037          1
# 27  Sample_0038          0
# 28  Sample_0039          1
# 29  Sample_0040          0
# 30  Sample_0043          1
# 31  Sample_0044          1
# 32  Sample_0045          1
# 33  Sample_0047          1
# 34  Sample_0052          1
# 35  Sample_0053          1
# 36  Sample_0057          1
# 37  Sample_0062          1
# 38  Sample_0074          0
# 39  Sample_0083          0
# 40  Sample_0085          1
# 41  Sample_0086          1
# 42  Sample_0087          1
# 43  Sample_0088          1
# 44  Sample_0089          0
# 45  Sample_0090          0
# 46  Sample_0091          1
# 47  Sample_0092          1
# 48  Sample_0093          1
# 49  Sample_0094          1
# 50  Sample_0095          0
# 51  Sample_0097          1
# 52  Sample_0099          0
# 53  Sample_0100          0
# 54  Sample_0101          0
# 55  Sample_0103          0
# 56  Sample_0105          1
# 57  Sample_0106          1
# 58  Sample_0107          0
# 59  Sample_0108          1
# 60  Sample_0109          1
# 61  Sample_0110          0
# 62  Sample_0111          0
# 63  Sample_0112          1
# 64  Sample_0114          1
# 65  Sample_0115          0
# 66  Sample_0116          0
# 67  Sample_0117          1
# 68  Sample_0118          1
# 69  Sample_0119          1
# 70  Sample_0120          0
# 71  Sample_0122          1
# 72  Sample_0123          0
# 73  Sample_0124          0
# 74  Sample_0125          0
# 75  Sample_0126          0
# 76  Sample_0128          1
# 77  Sample_0131          1
# 78  Sample_0133          0
# 79  Sample_0134          0

# %% [markdown]
# ## Preparation of labels from repository 2

# %%
r2_labels
r2_labels_v1['labels_v1'] = r2_labels_v1['label'].replace({'possible_responder': 1, 'possible_nonresponder': 0})
pd.set_option('display.max_rows', None)

r2_labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 r2_labels
# ----> 2 r2_labels_v1['labels_v1'] = r2_labels_v1['label'].replace({'possible_responder': 1, 'possible_nonresponder': 0})
#       3 pd.set_option('display.max_rows', None)
#       5 r2_labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
#
# NameError: name 'r2_labels_v1' is not defined

# %% [markdown]
# ## Preparation of labels from repository 3

# %%
r3_labels_v1 = r3_labels
r3_labels_v1
#r3_labels_v1['labels_v1'] = r3_labels_v1['label'].replace({'true_responder': 1,'responder_based_on_PFS': 1, 'true_nonresponder': 0})
#r3_labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
# Out:
#     Unnamed: 0    SAMPLE_ID                   label
# 0            0  Sample_0214          true_responder
# 1            1  Sample_0215          true_responder
# 2            2  Sample_0216  responder_based_on_PFS
# 3            3  Sample_0217          true_responder
# 4            4  Sample_0218          true_responder
# 5            5  Sample_0219          true_responder
# 6            6  Sample_0220          true_responder
# 7            7  Sample_0221  responder_based_on_PFS
# 8            8  Sample_0222          true_responder
# 9            9  Sample_0223       true_nonresponder
# 10          10  Sample_0224          true_responder
# 11          11  Sample_0225  responder_based_on_PFS
# 12          12  Sample_0226  responder_based_on_PFS
# 13          13  Sample_0227          true_responder
# 14          14  Sample_0228          true_responder
# 15          15  Sample_0229  responder_based_on_PFS
# 16          16  Sample_0230          true_responder
# 17          17  Sample_0231          true_responder
# 18          18  Sample_0232          true_responder
# 19          19  Sample_0233          true_responder
# 20          20  Sample_0234          true_responder
# 21          21  Sample_0235          true_responder
# 22          22  Sample_0236  responder_based_on_PFS
# 23          23  Sample_0237  responder_based_on_PFS
# 24          24  Sample_0238  responder_based_on_PFS
# 25          25  Sample_0239  responder_based_on_PFS
# 26          26  Sample_0240          true_responder
# 27          27  Sample_0241          true_responder
# 28          28  Sample_0242          true_responder
# 29          29  Sample_0243          true_responder
# 30          30  Sample_0244          true_responder
# 31          31  Sample_0245          true_responder
# 32          32  Sample_0246          true_responder
# 33          33  Sample_0247  responder_based_on_PFS
# 34          34  Sample_0248          true_responder
# 35          35  Sample_0249          true_responder
# 36          36  Sample_0250  responder_based_on_PFS
# 37          37  Sample_0251          true_responder
# 38          38  Sample_0252          true_responder
# 39          39  Sample_0253          true_responder
# 40          40  Sample_0254  responder_based_on_PFS
# 41          41  Sample_0255  responder_based_on_PFS

# %% [markdown]
# ## Merge all labels v1

# %%
labels_v1 = pd.concat([r1_labels_v1, r2_labels_v1, r3_labels_v1], ignore_index=True)
labels_v1 = labels_v1.drop(columns=['Unnamed: 0', 'label'], axis='columns')
labels_v1.to_csv('labels_v1.csv')
